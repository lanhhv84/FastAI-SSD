# %% [markdown]
# ### Import

# %% [markdown]
# #### Local

# %%
from pathlib import PosixPath

root = PosixPath('/mnt/188f6bc0-7ce9-4833-a30f-60f6ee8c4aef/Project')

# %% [markdown]
# #### Colab

# %%
# from google.colab import drive
# from pathlib import PosixPath


# drive.mount('/content/drive')
# root = PosixPath('/content/drive/My Drive/DS/')

# %%
import sys

sys.path.append(str(root/'lib'))

# %%
from xml.dom import minidom
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.nn.modules.upsampling import Upsample
import cv2
from PIL import Image
from tqdm.autonotebook import tqdm
from ssd import ssd_loss, truth_boxes, total_boxes
import matplotlib.pyplot  as plt
from torch.utils.data import Dataset, DataLoader
from os.path import isfile
from joblib import dump, load
from functools import partial
from fastai.train import clip_grad
from torchvision import transforms
from fastai.callbacks import *
from ssd import SSD
from fastai.vision import *
import imagesize
# Out:
# /home/hvlpr/anaconda3/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### VOC read

# %%
path = root/'yolo'
voc_path = path/'voc/VOCdevkit/VOC2012/'
images_path = voc_path/'JPEGImages'
anno_path = voc_path/'Annotations'

# %%
images_data = {}

# %%
# for anno in anno_path.iterdir():
    
#     boxes = []
#     classes = []
#     with minidom.parse(str(anno)) as xmldoc:
#         filename = xmldoc.getElementsByTagName('filename')[0].childNodes[0].data
#         bndboxes = xmldoc.getElementsByTagName('bndbox')
#         names = xmldoc.getElementsByTagName('name')
#         for i in range(len(bndboxes)):
#             bndbox = bndboxes[i]
#             xmin = bndbox.getElementsByTagName('xmin')[0].childNodes[0].data
#             xmax = bndbox.getElementsByTagName('xmax')[0].childNodes[0].data
#             ymin = bndbox.getElementsByTagName('ymin')[0].childNodes[0].data
#             ymax = bndbox.getElementsByTagName('ymax')[0].childNodes[0].data
#             box = [ymin, xmin, ymax, xmax]
#             boxes.append(box)
#             name = names[i].childNodes[0].data
#             classes.append(name)
#         images_data[filename] = [boxes, classes]

# %%
# dict_data = images_data

# %%
# classes = list(set([i for x in images_data.values() for i in x[1]]))

# %%
# classes_dict = {x: index for index, x in enumerate(classes)}
# classes_dict['background'] = len(classes_dict)

# %%
# index_dict = {val: key for key, val in classes_dict.items()}

# %%
# index_dict[len(index_dict)] = 'background'

# %%
# for key in dict_data:
#     val = dict_data[key]
# #     val[1] = [index_dict.get(x, classes_dict.get(x, index_dict.get(x))) for x in val[1]]
#     val[0] = [[float(v) for v in box] for box in val[0]]

# %%
# classes_dict['background'] = len(classes_dict)

# %%
# dump(dict_data, voc_path/'data.pkl')

# dump(classes_dict, voc_path/'dict.pkl')

dict_data = load(voc_path/'data.pkl')
classes_dict = load(voc_path/'dict.pkl')

# %% [markdown]
# ### Parameters

# %%
NBOXES = 3
N_CLASSES = len(classes_dict)
FEATURES = NBOXES*(5 + N_CLASSES)

TX = 0
TY = 1
TW = 2
TH = 3
CONF = 4
bs = 8

IOU_THRES=0.6

IMAGE_GRID = 26
IMAGE_SIZE = 300# 416 ## 
# label = [bouding box, (5), 26, 26]
BOX_SIZDE = IMAGE_SIZE / IMAGE_GRID
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

LOSS_REDUCTION = 'sum'

# %% [markdown]
# ### Data

# %% [markdown]
# #### Data

# %%
def roundboxes(boxes):
    return [[[b[1], b[0], b[1] + b[3], b[0] + b[2]] for b in boxes], ['face']*len(boxes)]

def emptyboxes():
    return [[[0, 0, 0, 0]], ['background']]

# %%
def label_func(x):
    x = PosixPath(x).name
    return dict_data.get(x, emptyboxes())

# %%
train_df = pd.DataFrame({'name': list(dict_data.keys())})

# %%
data = ObjectItemList.from_df(train_df, path=images_path).split_by_rand_pct()
pad_collate = partial(bb_pad_collate, pad_idx='background')

# %%
data = data.label_from_func(label_func)\
.transform(get_transforms(), size=IMAGE_SIZE, tfm_y=True)\
.databunch(bs=bs, val_bs=bs*2, collate_fn=bb_pad_collate)

# %%
data.show_batch(11)

# %%
# data.save(voc_path/'data.bin')

# %% [markdown]
# ### Test

# %%
batch = next(iter(data.train_dl))

# %%
batch[1][1].shape

# %%
batch_sample = 1
image = batch[0][batch_sample]
boxes = batch[1][0][batch_sample]

# %%
boxes = np.array([[-0.6910, -1.0000,  0.8046,  0.8126], [-0.0524, -0.5271,  0.4435, -0.3555], [-0.7457, -1.0000,  0.3988, -0.3220]])
boxes = (boxes + 1)*(IMAGE_SIZE/2)
boxes = [[x, y, w - x, h - y] for [y, x, h, w] in boxes]

# %%
np_image = image.permute(1, 2, 0).cpu().numpy()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np



# Create a Rectangle patch
for cord in boxes:
    [x, y, w, h] = [int(round(a)) for a in cord]
    print((x,y), (x+w,y+h))
    cv2.rectangle((np_image*255).astype('int32'), (x,y), (x+w,y+h), (0,255,0), 10)

# Display the image
plt.imshow(np_image)



plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np



# Create a Rectangle patch
for cord in boxes:
    [x, y, w, h] = [int(round(a)) for a in cord]
    print((x,y), (x+w,y+h))
    np_image = cv2.rectangle((np_image*255).astype('int32'), (x,y), (x+w,y+h), (0,255,0), 3)

# Display the image
plt.imshow(np_image)



plt.show()

# %% [markdown]
# ### Feed

# %%
from ssd import MobileNetv2SSD, MobileNetSSD

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

net = MobileNetSSD(N_CLASSES).to(device)

# %% [markdown]
# - Forward to calculate $(g_{c_x}, g_{c_y}, g_w, g_h)$
# - Identify corresponding prior $(\hat{c}_x, \hat{c}_y, \hat{w}, \hat{h})$
# - Calculate Predicted box
#     - $c_x = g_{c_x}*\hat{w} + \hat{c}_x$
#     - $c_y = g_{c_y}*\hat{h} + \hat{c}_y$
#     - $w = e^{g_{w}}*\hat{w}$
#     - $h = e^{g_{h}}*\hat{h}$
# - Calculate IoU
# - Match

# %% [markdown]
# - Create overlapping table between predicted and ground truth (8732*number of ground truth object)
# - Match each priors with greatest overlap
# - Categorize as positive and negative match
# - Calculate loss

# %% [markdown]
# ### Loss

# %%
from radam import RAdam

# %%
eps = 1e-3
ssd_loss = partial(ssd_loss, device=device, im_size=IMAGE_SIZE, eps=eps)

# %%
loss = partial(ssd_loss, n_classes=N_CLASSES, smoothl1=nn.SmoothL1Loss(reduction='sum'), cre=nn.CrossEntropyLoss(reduction='sum'), iou_thres=IOU_THRES)

# %%
ssd_metric = partial(truth_boxes, im_size=IMAGE_SIZE, thres=IOU_THRES, n_classes=N_CLASSES)

learn = Learner(data, net, loss_func=loss, opt_func=RAdam, metrics=[ssd_metric, total_boxes])
# learn = clip_grad(learn, clip=1)

# %%
callbacks = [EarlyStoppingCallback(learn, min_delta=1e-5, patience=3), SaveModelCallback(learn, name='model3')]
learn.callbacks = callbacks

# %%
# learn.lr_find()
# learn.recorder.plot()

# %%
learn.load('model3')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (13700 items)
# x: ObjectItemList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: ObjectCategoryList
# ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300)
# Path: /mnt/188f6bc0-7ce9-4833-a30f-60f6ee8c4aef/Project/yolo/voc/VOCdevkit/VOC2012/JPEGImages;
#
# Valid: LabelList (3425 items)
# x: ObjectItemList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: ObjectCategoryList
# ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300),ImageBBox (300, 300)
# Path: /mnt/188f6bc0-7ce9-4833-a30f-60f6ee8c4aef/Project/yolo/voc/VOCdevkit/VOC2012/JPEGImages;
#
# Test: None, model=MobileNetSSD(
#   (sigmoid): Sigmoid()
#   (fm1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#       (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (7): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (8): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (10): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (11): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (12): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (fm1_conf): Conv2d(512, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm1_loc): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm2): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (2): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (3): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (4): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (5): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (6): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (fm2_conf): Conv2d(1024, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm2_loc): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm3): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (fm3_conf): Conv2d(512, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm3_loc): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm4): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (fm4_conf): Conv2d(256, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm4_loc): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm5): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (fm5_conf): Conv2d(256, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm5_loc): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm6): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (fm6_conf): Conv2d(256, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fm6_loc): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ), opt_func=<class 'radam.RAdam'>, loss_func=functools.partial(<function ssd_loss at 0x7fd4dced1a60>, device=device(type='cuda'), im_size=300, eps=0.001, n_classes=24, smoothl1=SmoothL1Loss(), cre=CrossEntropyLoss(), iou_thres=0.6), metrics=[functools.partial(<function truth_boxes at 0x7fd4dced18c8>, im_size=300, thres=0.6, n_classes=24), <function total_boxes at 0x7fd4dced1950>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/mnt/188f6bc0-7ce9-4833-a30f-60f6ee8c4aef/Project/yolo/voc/VOCdevkit/VOC2012/JPEGImages'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[EarlyStoppingCallback
# learn: ...
# monitor: valid_loss
# mode: auto
# min_delta: -1e-05
# patience: 3, SaveModelCallback
# learn: ...
# monitor: valid_loss
# mode: auto
# every: improvement
# name: model3], layer_groups=[Sequential(
#   (0): Sigmoid()
#   (1): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#   (2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU()
#   (4): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU()
#   (10): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU()
#   (20): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#   (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU()
#   (23): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (24): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (25): ReLU()
#   (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (27): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#   (28): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU()
#   (30): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): ReLU()
#   (33): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#   (34): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (35): ReLU()
#   (36): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU()
#   (39): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#   (40): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU()
#   (42): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): ReLU()
#   (45): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (46): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#   (47): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): ReLU()
#   (49): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (51): ReLU()
#   (52): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#   (53): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (54): ReLU()
#   (55): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (56): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (57): ReLU()
#   (58): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#   (59): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): ReLU()
#   (61): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (62): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (63): ReLU()
#   (64): Conv2d(512, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (65): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (66): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (67): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#   (68): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (69): ReLU()
#   (70): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (71): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (72): ReLU()
#   (73): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#   (74): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (75): ReLU()
#   (76): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (77): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (78): ReLU()
#   (79): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#   (80): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (81): ReLU()
#   (82): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (83): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (84): ReLU()
#   (85): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   (86): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6), groups=512, bias=False)
#   (87): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (88): ReLU()
#   (89): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (90): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (91): ReLU()
#   (92): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (93): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (94): ReLU()
#   (95): Conv2d(1024, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (96): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (97): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#   (98): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (99): ReLU()
#   (100): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#   (101): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (102): ReLU()
#   (103): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (104): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (105): ReLU()
#   (106): Conv2d(512, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (107): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (108): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#   (109): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (110): ReLU()
#   (111): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#   (112): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (113): ReLU()
#   (114): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (115): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (116): ReLU()
#   (117): Conv2d(256, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (118): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (119): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#   (120): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (121): ReLU()
#   (122): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), groups=128, bias=False)
#   (123): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (124): ReLU()
#   (125): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (126): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (127): ReLU()
#   (128): Conv2d(256, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (129): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (130): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#   (131): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (132): ReLU()
#   (133): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), groups=128, bias=False)
#   (134): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (135): ReLU()
#   (136): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (137): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (138): ReLU()
#   (139): Conv2d(256, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (140): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )], add_time=True, silent=False)

# %%
learn.fit(100, lr=1e-3, wd=0.0005) # 9500

# %%
callbacks = [EarlyStoppingCallback(learn, min_delta=1e-5, patience=10), SaveModelCallback(learn, name='model3')]
learn.callbacks = callbacks

# %%
learn.fit(100, lr=1e-3, wd=0.0005) # 9500

# %%
list(net.parameters())

# %%
def isNanWeight(net):
    for param in net.parameters():
        assert torch.sum(torch.isnan(param)) == 0

# %%
isNanWeight(net)

# %% [markdown]
# ### Inference

# %%
def convert_pred(out, n_classes=N_CLASSES):
    loc, conf = out
    bs = loc[0].shape[0]
    ratios4 = [1, 2, 0.5, 1]
    ratios6 = [1, 2, 0.5, 3, 1/3, 1]
    
    ratios_map = [ ratios4, ratios6, ratios6, ratios6, ratios4, ratios4]
    scales = [0.1, 0.2, 0.375, 0.55, 0.725, 0.9]
    
    pred = []
    priors = []
    for i in range(len(loc)):
        # assert torch.sum(torch.isnan(loc[i])) == 0, "loc is NaN"
        loc[i] = loc[i].reshape(bs, -1, 4, loc[i].shape[-1], loc[i].shape[-1])
        conf[i] = conf[i].reshape(bs, -1, n_classes, loc[i].shape[-1], loc[i].shape[-1])
        
    """
        loc:
            - (4, 4, 38, 38)
            - (6, 4, 19, 19)
            - (6, 4, 10, 10)
            - (6, 4, 5, 5)
            - (4, 4, 3, 3)
            - (4, 4, 1, 1)
            
        conf:
            - (4, n_classes, 38, 38)
            - (6, n_classes, 19, 19)
            - (6, n_classes, 10, 10)
            - (6, n_classes, 5, 5)
            - (4, n_classes, 3, 3)
            - (4, n_classes, 1, 1)
        truth_loc: (bs, maxlen, 4)
        truth_conf: (bs, maxlen)
    """
    
    for index in range(len(loc)):
        prior = torch.zeros_like(loc[index]) # bs, -1, 4, loc[i].shape[-1], loc[i].shape[-1]
        # calculate prior (cx, cy)
        for row in range(prior.shape[-1]):
            for col in range(prior.shape[-1]):
                prior[..., 0, row, col] = (0.5 + row) / prior.shape[-1] # Prior cx
                prior[..., 1, row, col] = (0.5 + col) / prior.shape[-1] # prior cy
        # assert prior.max() <= 1
        # calculate prior (w, h)
        ratios = ratios_map[index]
        scale = scales[index]
        for i in range(len(ratios)):
            r = ratios[i]
            if i == len(ratios) - 1:
                scale = scale*1.5
            w = scale*np.sqrt(r)
            h = scale/np.sqrt(r)
            # w
            prior[..., i, 2, :, :]  = w/prior.shape[-1]
            prior[..., i, 3, :, :] = h/prior.shape[-1]
        # done prior
        # cx
        # assert torch.sum(torch.isnan(prior)) == 0, "prior is NaN"
        pred_box = torch.zeros_like(loc[index])
        pred_box[...,0,:,:] = loc[index][...,0,:,:]*prior[...,2,:,:] + prior[...,0,:,:]
        pred_box[...,1,:,:] = loc[index][...,1,:,:]*prior[...,3,:,:] + prior[...,1,:,:]
        pred_box[...,2,:,:] = torch.exp(loc[index][...,2,:,:])*prior[...,2,:,:]
        pred_box[...,3,:,:] = torch.exp(loc[index][...,3,:,:])*prior[...,3,:,:]
        priors.append(prior)
        print(pred_box.shape)
        pred_box = pred_box.permute(0, 2, 1, 3, 4).contiguous().view(bs, 4, -1)
        pred_box = torch.clamp(pred_box, min=0, max=1)
        # assert torch.sum(torch.isnan(pred_box)) == 0, "Pred is NaN"
        pred.append(pred_box)
    
    return torch.cat(pred, dim=2).cpu().detach().numpy()  # (bs, 4, 8732)

# %%
with torch.no_grad():
    test_data = next(iter(data.train_dl))
    test_out = net(test_data[0])
    out = convert_pred(test_out)
# Out:
# torch.Size([8, 4, 4, 38, 38])
# torch.Size([8, 6, 4, 19, 19])
# torch.Size([8, 6, 4, 10, 10])
# torch.Size([8, 6, 4, 5, 5])
# torch.Size([8, 4, 4, 3, 3])
# torch.Size([8, 4, 4, 1, 1])

# %%
test_data[0].shape
# Out:
# torch.Size([8, 3, 300, 300])

# %%
test_out[0][0].shape
# Out:
# torch.Size([8, 4, 4, 38, 38])

# %%
out.shape
# Out:
# (8, 4, 8732)

# %%
test_sample = test_data[0].cpu().numpy()

# %%
out_sample = out[0, ...]

# %%
test_sample = test_sample[0]

# %%
test_sample.shape
# Out:
# (3, 300, 300)

# %%
out_sample.shape
# Out:
# (4, 8732)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(test_sample.transpose(1, 2, 0))
